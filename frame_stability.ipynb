# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches

from edesign import *
from utility import *
from models import *
from edesign import *
from display import *

#setup autoreload
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
germs = [['CZ'],
         ['CZ', 'Z1', 'Z1', 'Z2'], 
         ['CZ', 'X2', 'X2', 'X1'],
         ['Y2', 'Y2', 'X1', 'CZ'],
         ['X2', 'Y1', 'CZ', 'Y2'],
         ['CZ', 'X1', 'X1', 'Y2']]
depths = [i+1 for i in range(1000)]

model = UnitaryGateSetModel_CZOnly()
edesign = RPEDesign(model, germs, depths)

# %%
x = 0.01*np.random.randn(15)
plt.bar(range(15), x)
plt.title('Random initial parameters')
plt.show()

# %%
for germ in germs:
    plot_cartan_signals(edesign, germ, x)
    plt.show()
    plt.figure()
